# %%
import pandas as pd
import numpy as np

# %%
adult =  pd.read_csv(r"D:\CTTC files\Datasets for practice\adult.csv", header = None)
adult
# Out:
#         0          1       2             3              4   \
# 0      age  workclass  fnlwgt     education  education.num
# 1       90          ?   77053       HS-grad              9
# 2       82    Private  132870       HS-grad              9
# 3       66          ?  186061  Some-college             10
# 4       54    Private  140359       7th-8th              4
# ...    ...        ...     ...           ...            ...
# 32557   22    Private  310152  Some-college             10
# 32558   27    Private  257302    Assoc-acdm             12
# 32559   40    Private  154374       HS-grad              9
# 32560   58    Private  151910       HS-grad              9
# 32561   22    Private  201490       HS-grad              9
#
#                        5                  6              7      8       9   \
# 0          marital.status         occupation   relationship   race     sex
# 1                 Widowed                  ?  Not-in-family  White  Female
# ...

# %%
adult.columns=['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','cpg','cpl','hpw','native','income']
adult
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 0      age  workclass  fnlwgt     education  education.num
# 1       90          ?   77053       HS-grad              9
# 2       82    Private  132870       HS-grad              9
# 3       66          ?  186061  Some-college             10
# 4       54    Private  140359       7th-8th              4
# ...    ...        ...     ...           ...            ...
# 32557   22    Private  310152  Some-college             10
# 32558   27    Private  257302    Assoc-acdm             12
# 32559   40    Private  154374       HS-grad              9
# 32560   58    Private  151910       HS-grad              9
# 32561   22    Private  201490       HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0          marital.status         occupation   relationship   race     sex
# 1                 Widowed                  ?  Not-in-family  White  Female
# ...

# %%
adult.head()
# Out:
#    age  workclass  fnlwgt     education  education_num  marital_status  \
# 0  age  workclass  fnlwgt     education  education.num  marital.status
# 1   90          ?   77053       HS-grad              9         Widowed
# 2   82    Private  132870       HS-grad              9         Widowed
# 3   66          ?  186061  Some-college             10         Widowed
# 4   54    Private  140359       7th-8th              4        Divorced
#
#           occupation   relationship   race     sex           cpg  \
# 0         occupation   relationship   race     sex  capital.gain
# 1                  ?  Not-in-family  White  Female             0
# 2    Exec-managerial  Not-in-family  White  Female             0
# 3                  ?      Unmarried  Black  Female             0
# 4  Machine-op-inspct      Unmarried  White  Female             0
#
#             cpl             hpw          native  income
# 0  capital.loss  hours.per.week  native.country  income
# ...

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32562 entries, 0 to 32561
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32562 non-null  object
#  1   workclass       32562 non-null  object
#  2   fnlwgt          32562 non-null  object
#  3   education       32562 non-null  object
#  4   education_num   32562 non-null  object
#  5   marital_status  32562 non-null  object
#  6   occupation      32562 non-null  object
#  7   relationship    32562 non-null  object
#  8   race            32562 non-null  object
#  9   sex             32562 non-null  object
#  10  cpg             32562 non-null  object
#  11  cpl             32562 non-null  object
#  12  hpw             32562 non-null  object
#  13  native          32562 non-null  object
#  14  income          32562 non-null  object
# dtypes: object(15)
# memory usage: 3.7+ MB

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# cpg               0
# cpl               0
# hpw               0
# native            0
# income            0
# dtype: int64

# %%
for i in adult.columns:
    print(i, '\n', adult[i].unique())
# Out:
# age
#  ['age' '90' '82' '66' '54' '41' '34' '38' '74' '68' '45' '52' '32' '51'
#  '46' '57' '22' '37' '29' '61' '21' '33' '49' '23' '59' '60' '63' '53'
#  '44' '43' '71' '48' '73' '67' '40' '50' '42' '39' '55' '47' '31' '58'
#  '62' '36' '72' '78' '83' '26' '70' '27' '35' '81' '65' '25' '28' '56'
#  '69' '20' '30' '24' '64' '75' '19' '77' '80' '18' '17' '76' '79' '88'
#  '84' '85' '86' '87']
# workclass
#  ['workclass' '?' 'Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc'
#  'Self-emp-inc' 'Local-gov' 'Without-pay' 'Never-worked']
# fnlwgt
#  ['fnlwgt' '77053' '132870' ... '34066' '84661' '257302']
# education
#  ['education' 'HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate'
#  'Prof-school' 'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc'
#  '1st-4th' '5th-6th' '12th' '9th' 'Preschool']
# education_num
#  ['education.num' '9' '10' '4' '6' '16' '15' '13' '14' '7' '12' '11' '2'
#  '3' '8' '5' '1']
# marital_status
# ...

# %%
adult.describe(include = 'all')
# Out:
#           age workclass  fnlwgt education education_num      marital_status  \
# count   32562     32562   32562     32562         32562               32562
# unique     74        10   21649        17            17                   8
# top        36   Private  164190   HS-grad             9  Married-civ-spouse
# freq      898     22696      13     10501         10501               14976
#
#             occupation relationship   race    sex    cpg    cpl    hpw  \
# count            32562        32562  32562  32562  32562  32562  32562
# unique              16            7      6      3    120     93     95
# top     Prof-specialty      Husband  White   Male      0      0     40
# freq              4140        13193  27816  21790  29849  31042  15217
#
#                native income
# count           32562  32562
# unique             43      3
# top     United-States  <=50K
# freq            29170  24720

# %%
cat_cols=[col for col in adult.columns if adult[col].dtype=='object']
cat_cols
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education_num',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'cpg',
#  'cpl',
#  'hpw',
#  'native',
#  'income']

# %%
for col in cat_cols:
    print(f"----------Column:{col}-------")
    print(adult[col].value_counts())
# Out:
# ----------Column:age-------
# age
# 36     898
# 31     888
# 34     886
# 23     877
# 35     876
#       ...
# 88       3
# 85       3
# 86       1
# age      1
# 87       1
# Name: count, Length: 74, dtype: int64
# ----------Column:workclass-------
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# workclass               1
# Name: count, dtype: int64
# ----------Column:fnlwgt-------
# fnlwgt
# 164190    13
# 203488    13
# 123011    13
# 126675    12
# 113364    12
#           ..
# 44419      1
# 442612     1
# 374833     1
# 207418     1
# 257302     1
# Name: count, Length: 21649, dtype: int64
# ----------Column:education-------
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# ...

# %%
c = 0
for i in adult.workclass:
    if i == '?':
        c = c+1
print('? =', c)
# Out:
# ? = 1836

# %%
c = 0
for i in adult.native:
    if i == '?':
        c = c+1
print('? =', c)
# Out:
# ? = 583

# %%
c = 0
for i in adult.occupation:
    if i == '?':
        c = c+1
print('? =', c)
# Out:
# ? = 1843

# %%
adult.workclass = adult.workclass.replace(' ?', np.nan)

# %%
adult.native = adult.native.replace(' ?', np.nan)

# %%
adult.occupation = adult.occupation.replace('?', np.nan)

# %%
adult.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# cpg                  0
# cpl                  0
# hpw                  0
# native               0
# income               0
# dtype: int64

# %%
adult = adult.dropna()
adult
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 0      age  workclass  fnlwgt     education  education.num
# 2       82    Private  132870       HS-grad              9
# 4       54    Private  140359       7th-8th              4
# 5       41    Private  264663  Some-college             10
# 6       34    Private  216864       HS-grad              9
# ...    ...        ...     ...           ...            ...
# 32557   22    Private  310152  Some-college             10
# 32558   27    Private  257302    Assoc-acdm             12
# 32559   40    Private  154374       HS-grad              9
# 32560   58    Private  151910       HS-grad              9
# 32561   22    Private  201490       HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0          marital.status         occupation   relationship   race     sex
# 2                 Widowed    Exec-managerial  Not-in-family  White  Female
# ...

# %%
for i in adult:
    print(i, sum(adult[i] == '?'))
# Out:
# age 0
# workclass 0
# fnlwgt 0
# education 0
# education_num 0
# marital_status 0
# occupation 0
# relationship 0
# race 0
# sex 0
# cpg 0
# cpl 0
# hpw 0
# native 556
# income 0
